# %%
# install apex for colab
# !cd /;git clone https://github.com/NVIDIA/apex;cd apex;pip install -v --no-cache-dir ./
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 7274 (delta 9), reused 6 (delta 0), pack-reused 7255
# Receiving objects: 100% (7274/7274), 13.86 MiB | 26.78 MiB/s, done.
# Resolving deltas: 100% (4910/4910), done.
# Created temporary directory: /tmp/pip-ephem-wheel-cache-sc9c6k36
# Created temporary directory: /tmp/pip-req-tracker-7k7lzopm
# Created requirements tracker '/tmp/pip-req-tracker-7k7lzopm'
# Created temporary directory: /tmp/pip-install-qc17vibz
# Processing /apex
#   Created temporary directory: /tmp/pip-req-build-u4v925p0
#   Added file:///apex to build tracker '/tmp/pip-req-tracker-7k7lzopm'
#     Running setup.py (path:/tmp/pip-req-build-u4v925p0/setup.py) egg_info for package from file:///apex
#     Running command python setup.py egg_info
#
#
#     torch.__version__  = 1.5.0+cu101
#
#
#     running egg_info
# ...

# %%
# check sys hardware
# !nvidia-smi

# import from github

import os

if not os.path.isdir("/content/drive/"):
  from google.colab import drive
  drive.mount('/content/drive')

from getpass import getpass
if os.path.isdir("/content/prj_m1/"):
  # !cd /content/prj_m1/; git pull
else:
  #user = getpass('GitHub user')
  user = "Mehechiger"
  #password = getpass('GitHub password')
  password = "" # repo went public...
  os.environ['GITHUB_AUTH'] = user + ':' + password
  # !cd /content/; git clone https://$GITHUB_AUTH@github.com/Mehechiger/prj_m1.git

import imp
helper_u = imp.new_module('helper')

def exec_u(f, helper=helper_u):
  exec(open(f).read(), helper.__dict__)

codes_loc = "/content/prj_m1/codes/"
os.chdir(codes_loc)
# Out:
# Sun Jun 21 19:15:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git checkout 'LSTM2_nothing'
# !git pull
"""
with open("B_1_BL_1_filippova_lstm.py", 'r') as f:
    print(f.read())
"""
exec_u("B_1_BL_1_filippova_lstm.py")
# Out:
# Branch 'LSTM2_nothing' set up to track remote branch 'LSTM2_nothing' from 'origin'.
# Switched to a new branch 'LSTM2_nothing'
# Already up to date.
#
#
# resume from checkpoint: checkpoint_epoch_7.pt
# 2020-06-21 19:15:32.774002
#
#
# using device: cuda
#
#
# train: 171865 examples
#
# val: 4294 examples
#
# test: 4297 examples
#
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# ...

# %%
#!rm /content/drive/My\ Drive/Colab_tmp/*.pt;rm /content/drive/My\ Drive/Colab_tmp/*.json;rm /content/drive/My\ Drive/Colab_tmp/*.log
#!sleep 1000000000
import torch
torch.cuda.empty_cache()
# !nvidia-smi
